# %% [markdown]
# # Jupyter Notebook Workshop - 2.1
#
# ### Reading DICOM Image and Metadata using PYDICOM

# %%
import os
cT1w_data_dir = './T1w_postContrast_Neuro/'
dcm_filename = '000120.dcm'
dcm_filepath = os.path.join(cT1w_data_dir, dcm_filename)

# %%
import pydicom
from pydicom.filereader import read_dicomdir

ds = pydicom.dcmread(dcm_filepath)
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 190
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.9328.50.16.281654496659260155563614379658381155324
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.27'
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 486
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM']
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.9328.50.16.281654496659260155563614379658381155324
# (0008, 0020) Study Date                          DA: '19040901'
# (0008, 0023) Content Date                        DA: '19040901'
# (0008, 0030) Study Time                          TM: ''
# (0008, 0032) Acquisition Time                    TM: '074955.247510'
# (0008, 0033) Content Time                        TM: ''
# (0008, 0050) Accession Number                    SH: '2819497684894126'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'SIEMENS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: ''
# (0008, 1030) Study Description                   LO: 'BRAIN^RESEARCH'
# (0008, 103e) Series Description                  LO: 'sag 3d gre +c'
# (0008, 1090) Manufacturer's Model Name           LO: ''
# (0008, 1150) Referenced SOP Class UID            UI: 1.3.6.1.4.1.9328.50.16.295504506656781074046411123909869020125
# (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.9328.50.16.221860239392707005792015444870506383145
# (0010, 0000) Group Length                        UL: 64
# (0010, 0010) Patient's Name                      PN: '281949'
# (0010, 0020) Patient ID                          LO: 'RIDER Neuro MRI-1023805636'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0012, 0000) Group Length                        UL: 74
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: 'CTP:NBIA Default w/ extra date removal:20100323:181510'
# (0013, 0000) Private Creator                     UN: b'4\x00\x00\x00'
# (0013, 0010) Private tag data                    LO: 'CTP'
# (0013, 1010) Private tag data                    UN: b'RIDER NEURO MRI\x00'
# (0013, 1013) Private tag data                    UN: b'88623004'
# (0018, 0000) Group Length                        UL: 462
# (0018, 0010) Contrast/Bolus Agent                LO: 'Magnevist'
# (0018, 0015) Body Part Examined                  CS: 'BRAIN'
# (0018, 0020) Scanning Sequence                   CS: 'GR'
# (0018, 0021) Sequence Variant                    CS: 'SP'
# (0018, 0022) Scan Options                        CS: ''
# (0018, 0023) MR Acquisition Type                 CS: '3D'
# (0018, 0024) Sequence Name                       SH: '*fl3d1'
# (0018, 0025) Angio Flag                          CS: 'N'
# (0018, 0050) Slice Thickness                     DS: "1.0"
# (0018, 0080) Repetition Time                     DS: "8.6"
# (0018, 0081) Echo Time                           DS: "4.11"
# (0018, 0083) Number of Averages                  DS: "1.0"
# (0018, 0084) Imaging Frequency                   DS: "63.676734"
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0086) Echo Number(s)                      IS: "0"
# (0018, 0087) Magnetic Field Strength             DS: "1.4939999580383"
# (0018, 0089) Number of Phase Encoding Steps      IS: "224"
# (0018, 0091) Echo Train Length                   IS: "1"
# (0018, 0093) Percent Sampling                    DS: "100.0"
# (0018, 0094) Percent Phase Field of View         DS: "100.0"
# (0018, 0095) Pixel Bandwidth                     DS: "150.0"
# (0018, 1000) Device Serial Number                LO: '25445'
# (0018, 1020) Software Versions                   LO: 'syngo MR 2004V 4VB11D'
# (0018, 1030) Protocol Name                       LO: 'sag 3d gre +c'
# (0018, 1041) Contrast/Bolus Volume               DS: "17.0"
# (0018, 1200) Date of Last Calibration            DA: '19031229'
# (0018, 1201) Time of Last Calibration            TM: '155156.000000'
# (0018, 1251) Transmit Coil Name                  SH: 'Body'
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: "20.0"
# (0018, 1315) Variable Flip Angle Flag            CS: 'N'
# (0018, 1316) SAR                                 DS: "0.09578327089548"
# (0018, 1318) dB/dt                               DS: "0.0"
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 0000) Group Length                        UL: 344
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.9328.50.16.338984301554101892670865995322384362242
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.9328.50.16.164211221753964606868669715363264852195
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "15"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: "73"
# (0020, 0032) Image Position (Patient)            DS: [14.144067764282, -139.89299583435, 128]
# (0020, 0037) Image Orientation (Patient)         DS: [0, 1, 0, 0, 0, -1]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.9328.50.16.298104612051800006342068154086600679216
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "14.144067764282"
# (0028, 0000) Group Length                        UL: 198
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: [1, 1]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 1127
# (0028, 1050) Window Center                       DS: "524.0"
# (0028, 1051) Window Width                        DS: "1079.0"
# (0028, 1052) Rescale Intercept                   DS: "0.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'PIXELVALUE'
# (0028, 1055) Window Center & Width Explanation   LO: 'Algo1'
# (0032, 0000) Group Length                        UL: 22
# (0032, 1060) Requested Procedure Description     LO: 'BRAIN RESEARCH'
# (0040, 0000) Group Length                        UL: 38
# (0040, 0244) Performed Procedure Step Start Date DA: '19040618'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'BRAIN^RESEARCH'
# (0088, 0000) Group Length                        UL: 70
# (0088, 0140) Storage Media File-set UID          UI: 1.3.6.1.4.1.9328.50.16.25238691347357500246954347537649273447
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 elements

# %%
ds.PatientName
# Out:
# '281949'

# %% [markdown]
# Lets view a slice

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

slice_data = ds.pixel_array

plt.imshow(slice_data, cmap="gray")
plt.show()
